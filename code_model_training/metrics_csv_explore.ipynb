# %%
import pandas as pd

# Path to your metrics file
csv_path = "/home/puneet/maninder/code_model_training/modelResults/her2st_stnet_224/result_vit_2025-11-12_00-56-07/metrics_result.csv"

# Load the CSV
df = pd.read_csv(csv_path)

# Filter for validation phase only
val_df = df[df["phase"] == "val"]

# Metrics of interest
metrics = [
    "pearson_mean_cell_wise", "pearson_mean_genewise",
    "spearman_mean_cell_wise", "spearman_mean_genewise",
    "l1_error_mean", "l2_errors_mean"
]

# Compute per-fold mean and std
fold_stats = val_df.groupby("fold")[metrics].agg(["mean", "std"])

# Compute overall mean and std across all folds
overall_stats = {
    metric: {
        "overall_mean": val_df[metric].mean(),
        "overall_std": val_df[metric].std()
    } for metric in metrics
}

# Convert to DataFrame
overall_stats_df = pd.DataFrame(overall_stats).T

print("\n=== Per-Fold Mean & Std ===")
print(fold_stats)

print("\n=== Overall Mean & Std ===")
print(overall_stats_df)
# Out:
# === Per-Fold Mean & Std ===
#      pearson_mean_cell_wise           pearson_mean_genewise            \
#                        mean       std                  mean       std
# fold
# 1                  0.529706  0.043479              0.297465  0.025039
# 2                  0.498930  0.030384              0.271962  0.022959
# 3                  0.534347  0.028937              0.294170  0.027983
# 4                  0.522130  0.054880              0.263442  0.045489
# 5                  0.458140  0.091099              0.220350  0.053142
#
#      spearman_mean_cell_wise           spearman_mean_genewise            \
#                         mean       std                   mean       std
# fold
# 1                   0.535586  0.044338               0.269687  0.020047
# 2                   0.491631  0.031179               0.255705  0.021566
# 3                   0.532521  0.028608               0.275028  0.025044
# 4                   0.526556  0.054357               0.240244  0.040984
# 5                   0.452250  0.097074               0.205440  0.051023
#
#      l1_error_mean           l2_errors_mean
#               mean       std           mean       std
# fold
# 1         1.974766  0.062746       7.933161  0.579535
# 2         2.132994  0.021111       8.889662  0.470609
# 3         2.263516  0.051213       8.992601  0.402346
# 4         2.083823  0.054611       8.667854  0.847656
# 5         2.279700  0.099369       9.834720  1.360680
#
# === Overall Mean & Std ===
#                          overall_mean  overall_std
# pearson_mean_cell_wise       0.520391     0.044518
# pearson_mean_genewise        0.282797     0.034917
# spearman_mean_cell_wise      0.520354     0.046617
# spearman_mean_genewise       0.261329     0.031184
# l1_error_mean                2.120528     0.124910
# l2_errors_mean               8.633877     0.767775

# %%
import pandas as pd

# Path to your metrics file
csv_path = "/home/puneet/maninder/code_model_training/modelResults/cscc_stnet_pretrained_224/result_vit_2025-11-14_12-17-19/metrics_result.csv"

# Load the CSV
df = pd.read_csv(csv_path)

# Filter for validation phase only
val_df = df[df["phase"] == "val"]

# Metrics of interest
metrics = [
    "pearson_mean_cell_wise", "pearson_mean_genewise",
    "spearman_mean_cell_wise", "spearman_mean_genewise",
    "l1_error_mean", "l2_errors_mean"
]

# Compute per-fold mean and std
fold_stats = val_df.groupby("fold")[metrics].agg(["mean", "std"])

# Compute overall mean and std across all folds
overall_stats = {
    metric: {
        "overall_mean": val_df[metric].mean(),
        "overall_std": val_df[metric].std()
    } for metric in metrics
}

# Convert to DataFrame
overall_stats_df = pd.DataFrame(overall_stats).T

print("\n=== Per-Fold Mean & Std ===")
print(fold_stats)

print("\n=== Overall Mean & Std ===")
print(overall_stats_df)
# Out:
# === Per-Fold Mean & Std ===
#      pearson_mean_cell_wise           pearson_mean_genewise            \
#                        mean       std                  mean       std
# fold
# 1                  0.381321  0.031441              0.090733  0.001844
# 2                  0.416408  0.043078              0.333764  0.011237
# 3                  0.480474  0.030679              0.390264  0.010312
# 4                  0.449709  0.039962              0.189229  0.008136
# 5                  0.548433  0.032327              0.411536  0.011006
#
#      spearman_mean_cell_wise           spearman_mean_genewise            \
#                         mean       std                   mean       std
# fold
# 1                   0.424018  0.022960               0.080459  0.002019
# 2                   0.382136  0.054252               0.279887  0.006396
# 3                   0.432233  0.037110               0.332864  0.007328
# 4                   0.444811  0.032563               0.178854  0.008239
# 5                   0.516998  0.036941               0.359436  0.012949
#
#      l1_error_mean           l2_errors_mean
#               mean       std           mean       std
# fold
# 1         3.108731  0.043153      15.388608  0.427097
# 2         2.615241  0.082983      13.405254  0.919540
# 3         2.751188  0.026218      14.328950  1.175656
# 4         2.861229  0.079821      13.577743  0.541572
# 5         2.731995  0.072824      12.566919  0.679010
#
# === Overall Mean & Std ===
#                          overall_mean  overall_std
# pearson_mean_cell_wise       0.457184     0.068047
# pearson_mean_genewise        0.288599     0.124487
# spearman_mean_cell_wise      0.440995     0.058599
# spearman_mean_genewise       0.250711     0.104428
# l1_error_mean                2.810516     0.178528
# l2_errors_mean              13.846742     1.249526

# %%
import pandas as pd

# Path to your metrics file
csv_path = "/home/puneet/maninder/code_model_training/modelResults/HisToGene_hist2st_845_224/result_vit_2025-11-18_03-11-02/metrics_result.csv"

# Load the CSV
df = pd.read_csv(csv_path)

# Filter for validation phase only
val_df = df[df["phase"] == "val"]

# Metrics of interest
metrics = [
    "pearson_mean_cell_wise", "pearson_mean_genewise",
    "spearman_mean_cell_wise", "spearman_mean_genewise",
    "l1_error_mean", "l2_errors_mean", "mape_mean"
]

# --- Step 1: Find the row with max spearman_mean_genewise per fold ---
best_rows = val_df.loc[val_df.groupby("fold")["spearman_mean_genewise"].idxmax()]

# --- Step 2: Compute mean and std across these best rows ---
best_stats = best_rows[metrics].agg(["mean", "std"])

print("\n=== Best (Max Spearman Gene-wise) Row per Fold ===")
print(best_rows[["fold", "epoch", "spearman_mean_genewise"] + metrics])

print("\n=== Mean & Std Across Best Folds ===")
print(best_stats)
# Out:
# === Best (Max Spearman Gene-wise) Row per Fold ===
#      fold  epoch  spearman_mean_genewise  pearson_mean_cell_wise  \
# 35    1.0   18.0                  0.1881                  0.5886
# 147   2.0   26.0                  0.1421                  0.6074
# 255   3.0   24.0                  0.1733                  0.5890
# 345   4.0   15.0                  0.1445                  0.6103
# 441   5.0   18.0                  0.1027                  0.5450
#
#      pearson_mean_genewise  spearman_mean_cell_wise  spearman_mean_genewise  \
# 35                  0.2014                   0.5920                  0.1881
# 147                 0.1415                   0.6142                  0.1421
# 255                 0.1870                   0.5921                  0.1733
# 345                 0.1420                   0.6139                  0.1445
# 441                 0.1016                   0.5476                  0.1027
#
#      l1_error_mean  l2_errors_mean  mape_mean
# 35          1.8398          7.6024    72.1723
# 147         1.8242          7.2519    70.3569
# 255         1.8965          8.0229    71.5397
# 345         1.8614          7.4652    72.3783
# 441         1.9050          8.1695    74.8708
#
# === Mean & Std Across Best Folds ===
#       pearson_mean_cell_wise  pearson_mean_genewise  spearman_mean_cell_wise  \
# mean                0.588060               0.154700                 0.591960
# std                 0.026096               0.039935                 0.027128
#
#       spearman_mean_genewise  l1_error_mean  l2_errors_mean  mape_mean
# mean                 0.15014       1.865380        7.702380  72.263600
# std                  0.03288       0.035015        0.384095   1.656692
